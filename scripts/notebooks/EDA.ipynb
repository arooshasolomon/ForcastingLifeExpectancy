# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_life = pd.read_csv("../data/life-expectancy.csv")
df_caloric = pd.read_csv("../data/daily-per-capita-caloric-supply.csv")
df_gdp = pd.read_csv("../data/gdp-per-capita-worldbank.csv")
df_health= pd.read_csv("../data/total-healthcare-expenditure-gdp.csv")

df_life

dfs = {}
dfs["Life Expentancy"] = df_life
dfs["Caloric Supply"] = df_caloric
dfs["GDP"] = df_gdp
dfs["Healthcare Expenditure"] = df_health

# %%
for key in dfs.keys():
    print(f'{key}\n{dfs[key].info()}')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21565 entries, 0 to 21564
# Data columns (total 4 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Entity                                                 21565 non-null  object
#  1   Code                                                   19609 non-null  object
#  2   Year                                                   21565 non-null  int64
#  3   Period life expectancy at birth - Sex: total - Age: 0  21565 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 674.0+ KB
# Life Expentancy
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12825 entries, 0 to 12824
# Data columns (total 4 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
# ...

# %%
df_life['Code'].value_counts()
# Out:
# Code
# SWE         273
# GBR         242
# FRA         208
# DNK         190
# ISL         186
#            ...
# JOR          74
# KIR          74
# OWID_KOS     74
# ZWE          74
# OWID_USS      2
# Name: count, Length: 239, dtype: int64

# %%
dfs['Life Expentancy']
# Out:
#             Entity Code  Year  \
# 0      Afghanistan  AFG  1950
# 1      Afghanistan  AFG  1951
# 2      Afghanistan  AFG  1952
# 3      Afghanistan  AFG  1953
# 4      Afghanistan  AFG  1954
# ...            ...  ...   ...
# 21560     Zimbabwe  ZWE  2019
# 21561     Zimbabwe  ZWE  2020
# 21562     Zimbabwe  ZWE  2021
# 21563     Zimbabwe  ZWE  2022
# 21564     Zimbabwe  ZWE  2023
#
#        Period life expectancy at birth - Sex: total - Age: 0
# 0                                                28.1563
# 1                                                28.5836
# 2                                                29.0138
# 3                                                29.4521
# 4                                                29.6975
# ...                                                  ...
# 21560                                            61.0603
# 21561                                            61.5300
# 21562                                            60.1347
# ...

# %%
dfs['Caloric Supply']
# Out:
#             Entity Code  Year  Daily calorie supply per person
# 0      Afghanistan  AFG  1961                        3054.9053
# 1      Afghanistan  AFG  1962                        2973.2468
# 2      Afghanistan  AFG  1963                        2751.7795
# 3      Afghanistan  AFG  1964                        3013.4424
# 4      Afghanistan  AFG  1965                        3017.7600
# ...            ...  ...   ...                              ...
# 12820     Zimbabwe  ZWE  2017                        2045.9998
# 12821     Zimbabwe  ZWE  2018                        2065.9985
# 12822     Zimbabwe  ZWE  2019                        2025.0006
# 12823     Zimbabwe  ZWE  2020                        2014.0009
# 12824     Zimbabwe  ZWE  2021                        2048.9993
#
# [12825 rows x 4 columns]

# %%
dfs['Healthcare Expenditure']
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2002
# 1     Afghanistan  AFG  2003
# 2     Afghanistan  AFG  2004
# 3     Afghanistan  AFG  2005
# 4     Afghanistan  AFG  2006
# ...           ...  ...   ...
# 4284     Zimbabwe  ZWE  2017
# 4285     Zimbabwe  ZWE  2018
# 4286     Zimbabwe  ZWE  2019
# 4287     Zimbabwe  ZWE  2020
# 4288     Zimbabwe  ZWE  2021
#
#       Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)
# 0                                                  9.44
# 1                                                  8.94
# 2                                                  9.81
# 3                                                  9.95
# 4                                                 10.62
# ...                                                 ...
# 4284                                               6.36
# 4285                                               4.67
# 4286                                               3.23
# ...

# %%
dfs['GDP']
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2000
# 1     Afghanistan  AFG  2001
# 2     Afghanistan  AFG  2002
# 3     Afghanistan  AFG  2003
# 4     Afghanistan  AFG  2004
# ...           ...  ...   ...
# 7058     Zimbabwe  ZWE  2019
# 7059     Zimbabwe  ZWE  2020
# 7060     Zimbabwe  ZWE  2021
# 7061     Zimbabwe  ZWE  2022
# 7062     Zimbabwe  ZWE  2023
#
#       GDP per capita, PPP (constant 2021 international $)
# 0                                             1617.8264
# 1                                             1454.1108
# 2                                             1774.3087
# 3                                             1815.9282
# 4                                             1776.9182
# ...                                                 ...
# 7058                                          3294.8062
# 7059                                          2987.2698
# 7060                                          3184.7854
# ...

# %%
df_life = df_life.loc[df_life['Code'] == 'USA']

plt.figure(figsize=(10,5))
plt.plot(df_life['Year'], df_life['Period life expectancy at birth - Sex: total - Age: 0'], marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy Over Time')
plt.grid(True)
plt.show()

# %%
df_life['Period life expectancy at birth - Sex: total - Age: 0'].describe()
# Out:
# count    125.000000
# mean      67.295984
# std        9.667386
# min       39.410000
# 25%       59.600000
# 50%       69.942800
# 75%       75.567700
# max       79.304300
# Name: Period life expectancy at birth - Sex: total - Age: 0, dtype: float64

# %%
df_caloric = df_caloric.loc[df_caloric['Code'] == 'USA']

plt.figure(figsize=(10,5))
plt.plot(df_caloric['Year'], df_caloric['Daily calorie supply per person'], marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Daily Caloric Supply')
plt.title('Daily Caloric Supply Over Time')
plt.grid(True)
plt.show()

# %%
df_caloric['Daily calorie supply per person'].describe()
# Out:
# count     124.000000
# mean     3366.565737
# std       267.788228
# min      2585.000000
# 25%      3200.000000
# 50%      3300.000000
# 75%      3587.389100
# max      3911.000000
# Name: Daily calorie supply per person, dtype: float64

# %%
df_health = df_health.loc[df_health['Code'] == 'USA']

plt.figure(figsize=(10,5))
plt.plot(df_health['Year'], df_health['Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)'], marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Healthcare Expenditure')
plt.title('Healthcare Expenditure Over Time')
plt.grid(True)
plt.show()

# %%
df_health['Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)'].describe()
# Out:
# count    22.000000
# mean     15.657727
# std       1.439004
# min      12.490000
# 25%      14.612500
# 50%      16.130000
# 75%      16.595000
# max      18.760000
# Name: Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%), dtype: float64

# %%
df_gdp = df_gdp.loc[df_gdp['Code'] == 'USA']

plt.figure(figsize=(10,5))
plt.plot(df_gdp['Year'], df_gdp['GDP per capita, PPP (constant 2021 international $)'], marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.title('GDP Over Time')
plt.grid(True)
plt.show()

# %%
df_gdp['GDP per capita, PPP (constant 2021 international $)'].describe()
# Out:
# count       34.000000
# mean     58327.717765
# std       8649.681385
# min      43742.027000
# 25%      52083.414250
# 50%      59702.019500
# 75%      64229.366000
# max      74577.510000
# Name: GDP per capita, PPP (constant 2021 international $), dtype: float64

# %%
# DF AGG

dfs = [dfs[key].loc[(dfs[key]['Year'] >= 2002) & (dfs[key]['Year'] <= 2021)] for key in dfs.keys()]

df1, df2, df3, df4 = dfs

# %%
df1 = df1.loc[df1['Code'] == 'USA']
df2 = df2.loc[df2['Code'] == 'USA']
df3 = df3.loc[df3['Code'] == 'USA']
df4 = df4.loc[df4['Code'] == 'USA']

# %%
dfs_new = [df1, df2, df3, df4]

merged_df = dfs[0]
for df in dfs[1:]:
    merged_df = merged_df.merge(df, on=["Entity", "Code", "Year"], how="outer")

merged_df.rename(columns={"Daily calorie supply per person": "Daily calorie supply",
                        "GDP per capita, PPP (constant 2021 international $)":"GDP per capita",
                        "Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)":"Health expenditure as percentage of GDP",
                        "Period life expectancy at birth - Sex: total - Age: 0":"Life expectancy"}, 
                        inplace=True)

# reset index and display
merged_df.reset_index(drop=True, inplace=True)

merged_df
# Out:
#            Entity Code  Year  Life expectancy  Daily calorie supply  \
# 0     Afghanistan  AFG  2002          56.2251             1930.5800
# 1     Afghanistan  AFG  2003          57.1713             1931.3407
# 2     Afghanistan  AFG  2004          57.8098             2005.8702
# 3     Afghanistan  AFG  2005          58.2468             1983.8942
# 4     Afghanistan  AFG  2006          58.5533             1980.5311
# ...           ...  ...   ...              ...                   ...
# 6189     Zimbabwe  ZWE  2017          60.2626             2045.9998
# 6190     Zimbabwe  ZWE  2018          60.9055             2065.9985
# 6191     Zimbabwe  ZWE  2019          61.0603             2025.0006
# 6192     Zimbabwe  ZWE  2020          61.5300             2014.0009
# 6193     Zimbabwe  ZWE  2021          60.1347             2048.9993
#
#       GDP per capita  Health expenditure as percentage of GDP
# 0          1774.3087                                     9.44
# ...

# %%
import seaborn as sns

corr_matrix = merged_df.select_dtypes(include=['number']).corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')
